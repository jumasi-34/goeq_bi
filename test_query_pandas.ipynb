# %%
# --- 자동 모듈 리로드 설정 ---
# %load_ext autoreload
# %autoreload 2: 모든 모듈을 매번 자동으로 다시 로드
# %autoreload 2

# %% [markdown]
# ## 임포트

# %%
# --- 공통 라이브러리 import ---
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append(r"D:\OneDrive - HKNC\@ Project_CQMS\# Workstation_2")

from _00_database.db_client import get_client
from _02_preprocessing.CQMS import df_4m_change as repo
from _02_preprocessing.HOPE import df_oeapp
from _02_preprocessing import helper_pandas
from _03_visualization import bi_301_OE_Quality_Issue_Dashboard as viz
from _05_commons import config

# %%
df = repo.filtered_4m_by_weekly(config.a_week_ago, config.today)
df['DOC_NO'] = df['DOC_NO'].str.replace('MANA-DOC', '4M-', regex=False)
df

# df.columns
# Out:
#              DOC_NO PLANT                    PURPOSE  \
# 0    4M--2023-00021    DP             Cost reduction
# 1    4M--2023-00020    IP  Nonconformity Improvement
# 2    4M--2023-00023    KP             Cost reduction
# 3    4M--2023-00024    TP  Nonconformity Improvement
# 4    4M--2023-00030    KP  Nonconformity Improvement
# ..              ...   ...                        ...
# 699  4M--2024-00212    CP    Performance Improvement
# 700  4M--2024-00198    MP  Nonconformity Improvement
# 701  4M--2025-00003    DP  Nonconformity Improvement
# 702  4M--2024-00089    JP    Performance Improvement
# 703  4M--2024-00017    KP             Cost reduction
#
#                                                SUBJECT STATUS REQUESTER  \
# 0                      Curing Productivity Improvement    NaN  21200031
# 1    Additional SNI and UTQG marking for OE Honda N...    NaN  60002485
# 2                                OE RR 적정화 및 가류 생산성 향상    NaN  21400008
# ...

# %% [markdown]
# ## 변수

# %%
year = 2025
start_date = config.a_week_ago
end_date = config.today

# %%
df = df_quality_issue.load_quality_issues_for_3_years(year)
display(df.head())
print(df.shape)
print(df.info())
# Out:
#                       OEQ GROUP PLANT STAGE     OEM     VEH             PJT  \
# DOC_NO
# QI-2023-00072  China OE Quality    JP    02  Toyota   Camry            015B
# QI-2024-00020  China OE Quality    CP    02    Ford  Mondeo       CD542 4DR
# QI-2024-00113  China OE Quality    CP    02    Ford  Mondeo       CD542 4DR
# QI-2025-00070  China OE Quality    JP    02      VW  Passat  MAGOTAN B8L PA
# QI-2025-00066  China OE Quality    JP    02      VW  Passat  MAGOTAN B8L PA
#
#                                                        ISSUE_ETC  \
# DOC_NO
# QI-2023-00072                    UST（Uneven sectional in Tread ）
# QI-2024-00020  The shoulder of the tire is abnormal and lacks...
# QI-2024-00113           胎侧表面起皮\r\nTire sidewall surface peeling.
# QI-2025-00070  FAW-VW reports that 29 unsold Magotan B8L new ...
# QI-2025-00066  According to the notification from FAW-VW, the...
#
#                                                      DESCRIPTION  \
# DOC_NO
# ...

# %%
df = df_quality_issue.load_sellin_data_for_3_years(year)
display(df.head())
print(df.shape)
print(df.info())
# Out:
#   PLANT  YYYY  MM  SUPP_QTY
# 0    CP  2023   1    156086
# 1    CP  2023   2    278924
# 2    CP  2023   3    328668
# 3    CP  2023   4    278657
# 4    CP  2023   5    300373
# (261, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   PLANT     261 non-null    object
#  1   YYYY      261 non-null    int64
#  2   MM        261 non-null    int64
#  3   SUPP_QTY  261 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 8.3+ KB
# None

# %%
df = df_quality_issue.load_sellin_by_ev(year)
display(df.head())
print(df.shape)
print(df.info())
# Out:
#   EV  SUPP_QTY
# 0  N    553008
# 1  Y     91621
# (2, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   EV        2 non-null      object
#  1   SUPP_QTY  2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 164.0+ bytes
# None

# %%
df = df_quality_issue.load_quality_issues_by_week(start_date, end_date)
display(df.head())
print(df.shape)
print(df.info())
# Out:
#                       OEQ GROUP PLANT STAGE     OEM      VEH        PJT  \
# DOC_NO
# QI-2023-00078  China OE Quality    JP    02  Toyota  Corolla       115D
# QI-2023-00116  China OE Quality    JP    02  Toyota  Corolla       115D
# QI-2024-00010  China OE Quality    JP    02      VW  T-Cross      VW216
# QI-2024-00007  China OE Quality    CP    02    Ford   Mondeo  CD542 4DR
# QI-2024-00020  China OE Quality    CP    02    Ford   Mondeo  CD542 4DR
#
#                                                        ISSUE_ETC  \
# DOC_NO
# QI-2023-00078  Reverse marking.\r\nRight：Marking in DOT side\...
# QI-2023-00116  The Assembly plant found a 115D tire without y...
# QI-2024-00010  S/W  bulge.\r\nLE (Local Engineer in Spain(Aug...
# QI-2024-00007  FORD 2 plant maintenance area found 1 tire wit...
# QI-2024-00020  The shoulder of the tire is abnormal and lacks...
#
#                                                      DESCRIPTION  \
# DOC_NO
# ...

# %%
df = df_quality_issue.load_ongoing_quality_issues()
display(df.head())
print(df.shape)
print(df.info())
# Out:
#             DOC_NO          OEQ GROUP PLANT STAGE OEM     VEH             PJT  \
# 180  QI-2025-00039  Europe OE Quality    MP    02  VW    ID.4     VW316/6EU_B
# 20   QI-2025-00066   China OE Quality    JP    02  VW  Passat  MAGOTAN B8L PA
# 21   QI-2025-00067   China OE Quality    JP    02  VW  Passat  MAGOTAN B8L PA
# 23   QI-2025-00065   China OE Quality    JP    02  VW    Bora     BORA MQB PA
# 24   QI-2025-00064   China OE Quality    CP    02  VW   Jetta       NCS NF PA
#
#                                              ISSUE_ETC  \
# 180  After the delivery of the Volkswagen ID.4, vib...
# 20   According to the notification from FAW-VW, the...
# 21   According to the notification from FAW-VW, the...
# 23   According to the notification from FAW-VW, the...
# 24   According to the notification from FAW-VW, the...
#
#                                     DESCRIPTION  \
# 180  Trackback production and quality records.
# 20                     Goodwill  implementation
# ...

# %%
df = df_quality_issue.summarize_ongoing_quality_by_plant()
display(df.head())
print(df.shape)
print(df.info())
# Out:
#        count
# PLANT
# JP         6
# CP         1
# KP         1
# MP         1
# TP         1
# (5, 1)
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, JP to TP
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   5 non-null      int64
# dtypes: int64(1)
# memory usage: 80.0+ bytes
# None

# %%
df = df_quality_issue.summarize_ongoing_quality_by_month()
display(df.head())
print(df.shape)
print(df.info())
# Out:
#             count
# REG_DATE
# 2025-02-28      1
# 2025-03-31      0
# 2025-04-30      6
# 2025-05-31      3
# (4, 1)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4 entries, 2025-02-28 to 2025-05-31
# Freq: ME
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   4 non-null      int64
# dtypes: int64(1)
# memory usage: 64.0 bytes
# None

# %%
df = df_quality_issue.aggregate_oeqi_by_plant_monthly(year)
display(df)
print(df.shape)
print(df.info())
# Out:
#      YYYY  MM PLANT  count  SUPP_QTY  count_cumsum  SUPP_QTY_cumsum  OEQI
# 0    2023   1    CP      0  156086.0             0         156086.0   0.0
# 1    2023   1    DP      0  177674.0             0         177674.0   0.0
# 2    2023   1    HP      0  160792.0             0         160792.0   0.0
# 3    2023   1    IP      0   78782.0             0          78782.0   0.0
# 4    2023   1    JP      0  406405.0             0         406405.0   0.0
# ..    ...  ..   ...    ...       ...           ...              ...   ...
# 319  2025  12    JP      0       NaN             6              NaN   NaN
# 320  2025  12    KP      0       NaN             2              NaN   NaN
# 321  2025  12    MP      0       NaN             5              NaN   NaN
# 322  2025  12    OT      0       NaN             0              NaN   NaN
# 323  2025  12    TP      0       NaN             7              NaN   NaN
#
# [324 rows x 8 columns]
# (324, 8)
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
df = df_quality_issue.aggregate_oeqi_by_plant_yearly(year)
display(df)
print(df.shape)
print(df.info())
# Out:
#   PLANT  YYYY  count       MTTC   REG_PRD   RTN_PRD    CTM_PRD  COMP_PRD  \
# 0    CP  2025      1       17.0       0.0       0.0       17.0      <NA>
# 1    DP  2025      0       <NA>      <NA>      <NA>       <NA>      <NA>
# 2    HP  2025      1        8.0       1.0      <NA>        5.0       2.0
# 3    IP  2025      1       42.0      21.0       0.0       11.0      10.0
# 4    JP  2025      6  13.833333  0.166667  1.166667       13.5       1.0
# 5    KP  2025      2       15.5       2.0       0.0       12.0       1.5
# 6    MP  2025      5        7.0       0.0       3.0        5.4       1.6
# 7    OT  2025      0       <NA>      <NA>      <NA>       <NA>      <NA>
# 8    TP  2025      7  19.142857  1.285714      -1.0  14.142857  4.333333
#
#    SUPP_QTY      OEQI
# 0    794151  1.259206
# 1   1082003  0.000000
# 2   1093200  0.914746
# 3   1439734  0.694573
# 4   4356531  1.377243
# 5   2582645  0.774400
# 6   4813177  1.038815
# 7    105176  0.000000
# 8   1671388  4.188136
# ...

# %%
df = df_quality_issue.aggregate_oeqi_by_global_monthly(year)
display(df)
print(df.shape)
print(df.info())
# Out:
#     YYYY  MM  count  SUPP_QTY  count_cumsum  SUPP_QTY_cumsum      OEQI
# 0   2023   1    9.0   1893620           9.0          1893620  4.752802
# 1   2023   2   13.0   4018738          22.0          5912358  3.721020
# 2   2023   3    3.0   4562090          25.0         10474448  2.386761
# 3   2023   4    3.0   4299805          28.0         14774253  1.895189
# 4   2023   5    2.0   4592590          30.0         19366843  1.549039
# 5   2023   6    7.0   4622136          37.0         23988979  1.542375
# 6   2023   7   11.0   4054802          48.0         28043781  1.711609
# 7   2023   8    1.0   3981854          49.0         32025635  1.530024
# 8   2023   9    6.0   4223770          55.0         36249405  1.517266
# 9   2023  10   15.0   4578216          70.0         40827621  1.714526
# 10  2023  11    5.0   4646772          75.0         45474393  1.649280
# 11  2023  12    2.0   4023567          77.0         49497960  1.555620
# ...

# %%
df = df_quality_issue.aggregate_oeqi_by_global_yearly(year)
display(df)
print(df.shape)
print(df.info())
# Out:
#    YYYY  count       MTTC    REG_PRD    RTN_PRD    CTM_PRD  COMP_PRD  \
# 0  2023     77  45.545455  21.987013  39.962963  20.173333  3.960526
# 1  2024     66  21.166667   3.772727        3.4  12.848485  4.545455
# 2  2025     23  15.217391   1.565217        1.0  11.478261     3.125
#
#    SUPP_QTY      OEQI
# 0  49497960  1.555620
# 1  49775252  1.325960
# 2  17938005  1.282194
# (3, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   YYYY      3 non-null      int32
#  1   count     3 non-null      int64
#  2   MTTC      3 non-null      Float64
#  3   REG_PRD   3 non-null      Float64
#  4   RTN_PRD   3 non-null      Float64
#  5   CTM_PRD   3 non-null      Float64
#  6   COMP_PRD  3 non-null      Float64
#  7   SUPP_QTY  3 non-null      int64
#  8   OEQI      3 non-null      float64
# dtypes: Float64(5), float64(1), int32(1), int64(2)
# ...

# %%
df = df_quality_issue.aggregate_oeqi_by_goeq_monthly(year)
display(df)
print(df.shape)
print(df.info())
# Out:
#             OEQ GROUP  MM  count  cum_count  SUPP_QTY  CUM_SUPP_QTY      OEQI
# 10       G.OE Quality   1      1          1   1158171       1158171  0.863430
# 11       G.OE Quality   2      1          2   1266475       2424646  0.824863
# 12       G.OE Quality   3      0          2   1269143       3693789  0.541449
# 13       G.OE Quality   4      1          3   1188984       4882773  0.614405
# 14       G.OE Quality   5      0          3    221609       5104382  0.587730
# 0    China OE Quality   1      1          1   1400009       1400009  0.714281
# 1    China OE Quality   2      1          2   1237686       2637695  0.758238
# 2    China OE Quality   3      0          2   1551065       4188760  0.477468
# 3    China OE Quality   4      5          7   1702442       5891202  1.188213
# 4    China OE Quality   5      1          8    352680       6243882  1.281254
# 5   Europe OE Quality   1      3          3   1018147       1018147  2.946529
# ...

# %%
df = df_quality_issue.aggregate_oeqi_by_goeq_yearly(year)
display(df)
print(df.shape)
print(df.info())
# Out:
#            OEQ GROUP  count       MTTC   REG_PRD  RTN_PRD    CTM_PRD  COMP_PRD
# 0       G.OE Quality      3  24.333333  8.333333      0.0  11.666667  4.333333
# 1   China OE Quality      8       13.5      0.25      1.0     12.875       1.5
# 2  Europe OE Quality      5        7.0       0.0      3.0        5.4       1.6
# 3      NA OE Quality      7  19.142857  1.285714     -1.0  14.142857  4.333333
# (4, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OEQ GROUP  4 non-null      category
#  1   count      4 non-null      int64
#  2   MTTC       4 non-null      Float64
#  3   REG_PRD    4 non-null      Float64
#  4   RTN_PRD    4 non-null      Float64
#  5   CTM_PRD    4 non-null      Float64
#  6   COMP_PRD   4 non-null      Float64
# dtypes: Float64(5), category(1), int64(1)
# memory usage: 552.0 bytes
# None

# %%
dfs = df_quality_issue.compare_quality_by_ev_group(year)
for df in dfs:
    display(df)
    print(df.shape)
    print(df.info())
# Out:
#                        OEQ GROUP PLANT STAGE             OEM          VEH  \
# DOC_NO
# QI-2025-00070   China OE Quality    JP    02              VW       Passat
# QI-2025-00066   China OE Quality    JP    02              VW       Passat
# QI-2025-00067   China OE Quality    JP    02              VW       Passat
# QI-2025-00040   China OE Quality    JP    02              VW       Tayron
# QI-2025-00065   China OE Quality    JP    02              VW         Bora
# QI-2025-00064   China OE Quality    CP    02              VW        Jetta
# QI-2025-00072   China OE Quality    JP    02       Leapmotor          C11
# QI-2025-00006   China OE Quality    HP    02            Ford     F-Series
# QI-2025-00030       G.OE Quality    KP    02              VW        Jetta
# QI-2025-00058       G.OE Quality    KP    02              GM  Trailblazer
# QI-2025-00015  Europe OE Quality    MP    02              VW        Enyaq
# QI-2025-00043  Europe OE Quality    MP    02  Renault-Nissan         Juke
# ...

# %%
df = df_quality_issue.pivot_quality_by_week_and_status(start_date, end_date)
display(df)
print(df.shape)
print(df.info())
# Out:
# Status   PLANT  Open  Open & Close  Close  On-going
# 0           DP     0             0      0         0
# 1           KP     1             0      0         0
# 2           JP     2             0      0         4
# 3           HP     0             0      0         0
# 4           CP     0             0      0         1
# 5           MP     0             0      0         1
# 6           IP     0             0      0         0
# 7           TP     0             0      0         1
# 8       Global     3             0      0         7
# (9, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PLANT         9 non-null      object
#  1   Open          9 non-null      int64
#  2   Open & Close  9 non-null      int64
#  3   Close         9 non-null      int64
#  4   On-going      9 non-null      int64
# dtypes: int64(4), object(1)
# ...

# %% [markdown]
# # 나중에 확인할 함수

# %%
sqlite_query = """--sql
SELECT * 
FROM sellin_monthly_agg
"""
df_sellin = get_client('sqlite').execute(sqlite_query)
df_sellin = helper_pandas.standardize_columns_uppercase(df_sellin)
df_sellin = df_sellin[df_sellin['RE/OE'] == 'OE']
df_sellin[['YYYY', 'MM']] = df_sellin[['YYYY', 'MM']].astype('int')

df_app = df_oeapp.load_oeapp_df()
df_app = helper_pandas.standardize_columns_uppercase(df_app)

merge_df = pd.merge(df_sellin, df_app[["PLANT", "M_CODE"]], how='left', on = 'M_CODE')
merge_df = merge_df.groupby(['PLANT', 'YYYY', 'MM'], observed = False)['SUPP_QTY'].sum().reset_index()

# %%
display(merge_df)
print(merge_df.shape)
print(merge_df.info())
# Out:
#     PLANT  YYYY  MM  SUPP_QTY
# 0      CP  2023   1    176668
# 1      CP  2023   2    309726
# 2      CP  2023   3    367213
# 3      CP  2023   4    294761
# 4      CP  2023   5    350197
# ..    ...   ...  ..       ...
# 256    TP  2025   1    359628
# 257    TP  2025   2    378092
# 258    TP  2025   3    494334
# 259    TP  2025   4    427483
# 260    TP  2025   5     92227
#
# [261 rows x 4 columns]
# (261, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   PLANT     261 non-null    object
#  1   YYYY      261 non-null    int64
#  2   MM        261 non-null    int64
#  3   SUPP_QTY  261 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 8.3+ KB
# None

# %%
df = df_quality_issue.load_sellin_data_for_3_years(year)
print(df.shape)
print(df.info())
# Out:
# (261, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   PLANT     261 non-null    object
#  1   YYYY      261 non-null    int64
#  2   MM        261 non-null    int64
#  3   SUPP_QTY  261 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 8.3+ KB
# None

# %%
df = df_quality_issue.aggregate_oeqi_by_plant_monthly(year)
display(df[df['MM']==1])
print(df.shape)
print(df.info())
# Out:
#      YYYY  MM PLANT  count   SUPP_QTY  count_cumsum  SUPP_QTY_cumsum  \
# 0    2023   1    CP      0   156086.0             0         156086.0
# 1    2023   1    DP      0   177674.0             0         177674.0
# 2    2023   1    HP      0   160792.0             0         160792.0
# 3    2023   1    IP      0    78782.0             0          78782.0
# 4    2023   1    JP      0   406405.0             0         406405.0
# 5    2023   1    KP      0   349665.0             0         349665.0
# 6    2023   1    MP      5   378101.0             5         378101.0
# 7    2023   1    OT      0    17200.0             0          17200.0
# 8    2023   1    TP      4   168915.0             4         168915.0
# 108  2024   1    CP      1   331480.0             1         331480.0
# 109  2024   1    DP      0   214882.0             0         214882.0
# 110  2024   1    HP      1   271348.0             1         271348.0
# 111  2024   1    IP      2   256669.0             2         256669.0
# ...

# %%
df_app = df_oeapp.load_oeapp_df()
df_app = helper_pandas.standardize_columns_uppercase(df_app)
df_app = df_app[["PLANT", "M_CODE"]].drop_duplicates()
df_app
# Out:
#      PLANT   M_CODE
# 0       MP  1022601
# 1       MP  1023482
# 3       MP  1021310
# 4       MP  1023846
# 5       MP  1024622
# ...    ...      ...
# 1700    MP  1013117
# 1701    MP  1013116
# 1702    HP  3003448
# 1703    KP  3003748
# 1706    JP  1005903
#
# [1424 rows x 2 columns]

# %%
global_yearly = repo.aggregate_oeqi_by_global_yearly(2025)
global_yearly
# Out:
#    YYYY  count       MTTC    REG_PRD    RTN_PRD    CTM_PRD  COMP_PRD  \
# 0  2023     77  45.545455  21.987013  39.962963  20.173333  3.960526
# 1  2024     66  21.166667   3.772727        3.4  12.848485  4.545455
# 2  2025     23  15.217391   1.565217        1.0  11.478261     3.125
#
#    SUPP_QTY      OEQI
# 0  49497960  1.555620
# 1  49775252  1.325960
# 2  18199285  1.263786

# %%
df = repo.load_sellin_data_for_3_years(2023)
df
# Out:
#    PLANT  YYYY  MM  SUPP_QTY
# 0     CP  2023   2    140459
# 1     CP  2023   3    164134
# 2     CP  2023   4    138984
# 3     CP  2023   5    150084
# 4     CP  2023   6    165306
# ..   ...   ...  ..       ...
# 94    TP  2023   8    218940
# 95    TP  2023   9    197741
# 96    TP  2023  10    194754
# 97    TP  2023  11    199429
# 98    TP  2023  12    149069
#
# [99 rows x 4 columns]

# %%
year = config.this_year
global_yearly = repo.aggregate_oeqi_by_global_yearly(year)
viz.draw_three_years_oeqi(global_yearly)
global_yearly
# Out:
#    YYYY  count       MTTC    REG_PRD    RTN_PRD    CTM_PRD  COMP_PRD  \
# 0  2023     77  45.545455  21.987013  39.962963  20.173333  3.960526
# 1  2024     66  21.166667   3.772727        3.4  12.848485  4.545455
# 2  2025     23  15.217391   1.565217        1.0  11.478261     3.125
#
#    SUPP_QTY      OEQI
# 0  23575083  3.266160
# 1  24856265  2.655266
# 2   8876197  2.591200

# %%
df = repo.load_quality_issues_for_3_years(2025)
df =df[df['RETURN_YN'] == 'Y']
df
# Out:
#                       OEQ GROUP PLANT STAGE             OEM         VEH  \
# DOC_NO
# QI-2024-00020  China OE Quality    CP    02            Ford      Mondeo
# QI-2025-00070  China OE Quality    JP    02              VW      Passat
# QI-2025-00066  China OE Quality    JP    02              VW      Passat
# QI-2025-00067  China OE Quality    JP    02              VW      Passat
# QI-2025-00040  China OE Quality    JP    02              VW      Tayron
# ...                         ...   ...   ...             ...         ...
# QI-2024-00137     NA OE Quality    TP    02           Honda       Pilot
# QI-2024-00081     NA OE Quality    TP    02  Renault-Nissan  Pathfinder
# QI-2025-00050     NA OE Quality    TP    02  Renault-Nissan    Frontier
# QI-2023-00033  China OE Quality    JP    02             BMW          X5
# QI-2023-00115  China OE Quality    JP    02              VW      Tiguan
#
#                           PJT  \
# DOC_NO
# QI-2024-00020       CD542 4DR
# ...

# %%
df = repo.load_quality_issues_for_3_years(2025)
df = df[df['PLANT'] == 'JP']
df = df[df['YYYY'] == 2025]
df
# Out:
#                       OEQ GROUP PLANT STAGE        OEM     VEH  \
# DOC_NO
# QI-2025-00070  China OE Quality    JP    02         VW  Passat
# QI-2025-00066  China OE Quality    JP    02         VW  Passat
# QI-2025-00067  China OE Quality    JP    02         VW  Passat
# QI-2025-00040  China OE Quality    JP    02         VW  Tayron
# QI-2025-00065  China OE Quality    JP    02         VW    Bora
# QI-2025-00072  China OE Quality    JP    02  Leapmotor     C11
#
#                           PJT  \
# DOC_NO
# QI-2025-00070  MAGOTAN B8L PA
# QI-2025-00066  MAGOTAN B8L PA
# QI-2025-00067  MAGOTAN B8L PA
# QI-2025-00040        A SUV PA
# QI-2025-00065     BORA MQB PA
# QI-2025-00072             C11
#
#                                                        ISSUE_ETC  \
# DOC_NO
# QI-2025-00070  FAW-VW reports that 29 unsold Magotan B8L new ...
# QI-2025-00066  According to the notification from FAW-VW, the...
# QI-2025-00067  According to the notification from FAW-VW, the...
# ...
